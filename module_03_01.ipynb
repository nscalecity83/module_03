# %% [markdown]
# <a href="https://colab.research.google.com/github/nscalecity83/module_03/blob/main/module_03_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Это мое первое текстовое поле

# %%
print('Это мое первое кодовое поле')
# Out:
# Это мое первое текстовое поле
